# %%
import nltk

# %%
with open("texto_exemplo.txt") as f:
    texto = f.read()
texto
# Out:
# "Deep in the valley, surrounded by towering hills and dense forests, lies the quaint village of Meadowvale. It's a place seemingly frozen in time, where traditions are cherished, and the hustle of modern life feels like a distant concept. The village, with its cobblestone streets and thatched-roof cottages, exudes an aura of timeless charm.\n\nMeadowvale is known for its vibrant community. The villagers, with their warm smiles and open hearts, create an atmosphere of genuine camaraderie and mutual support. Each morning, they greet each other at the local market, a bustling hub of activity where fresh produce, homemade goods, and colorful crafts are exchanged with friendly banter.\n\nThe village school, a quaint building with ivy-clad walls, is the pride of Meadowvale. Here, children learn not just academics, but also the values of friendship, respect for nature, and the importance of community. The teachers are dedicated and nurturing, often going beyond their duties to ensure every child flourishes.\n\nIn the heart of the village stands the old oak tree, a legendary figure in Meadowvale's history. It's said that the tree has been there since the founding of the village, its branches bearing witness to generations of change and growth. Under its shade, villagers often gather for celebrations, festivals, and on warm, sunny days, simply to enjoy each other's company.\n\nAs the day progresses, the aroma of freshly baked bread and pastries wafts from the bakery, a favorite stop for young and old alike. The baker, with his flour-dusted apron and ever-present smile, is an expert at his craft, baking loaves that are the perfect blend of crusty and soft.\n\nAdjacent to the bakery is the village caf̩, a cozy spot where locals sip coffee, exchange news, and occasionally, burst into spontaneous music sessions. The caf̩ walls are adorned with photographs and paintings, a testament to the artistic talents of the village inhabitants.\n\nMeadowvale's surrounding countryside is a patchwork of lush fields, meandering streams, and wildflower meadows. Farmers tend their land with care and reverence, following methods passed down through generations. They work in harmony with the land, ensuring that their practices are sustainable and environmentally friendly.\n\nAs evening approaches, the village's pace slows down. The streets, once filled with the sounds of daily life, become quiet, save for the gentle clinking of dishes from the homes as families gather for dinner. These meals are often communal affairs, where stories are shared, and laughter rings through the walls.\n\nTwice a month, the village hosts a dance in the town hall. These events are the highlight of Meadowvale's social calendar, with everyone, young and old, participating. The dances are lively, filled with music, joy, and a sense of togetherness that is the heart of this community.\n\nAs night falls, the sky above Meadowvale becomes a canvas of stars, unmarred by city lights. The villagers, who know the importance of preserving the beauty of their natural surroundings, take a moment to gaze at the night sky, finding peace in its vastness.\n\nIn Meadowvale, life may seem simple, but it is rich in ways that matter. Here, people understand the value of connections, of living in tune with nature, and of preserving traditions that bind them together. It is a place where every individual contributes to the tapestry of the community, creating a life that is deeply fulfilling and harmonious."

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('punkt')
nltk.download('words')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\julio\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\julio\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\julio\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\julio\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
words = nltk.word_tokenize(texto)

# %%
pos = nltk.pos_tag(words)
pos
# Out:
# [('Deep', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('valley', 'NN'),
#  (',', ','),
#  ('surrounded', 'VBN'),
#  ('by', 'IN'),
#  ('towering', 'VBG'),
#  ('hills', 'NNS'),
#  ('and', 'CC'),
#  ('dense', 'NN'),
#  ('forests', 'NNS'),
#  (',', ','),
#  ('lies', 'VBZ'),
#  ('the', 'DT'),
#  ('quaint', 'JJ'),
#  ('village', 'NN'),
#  ('of', 'IN'),
#  ('Meadowvale', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('seemingly', 'RB'),
#  ('frozen', 'VBN'),
#  ('in', 'IN'),
#  ('time', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('traditions', 'NNS'),
#  ('are', 'VBP'),
#  ('cherished', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('hustle', 'NN'),
#  ('of', 'IN'),
#  ('modern', 'JJ'),
#  ('life', 'NN'),
#  ('feels', 'NNS'),
#  ('like', 'IN'),
#  ('a', 'DT'),
#  ('distant', 'JJ'),
#  ('concept', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('village', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('its', 'PRP$'),
#  ('cobblestone', 'NN'),
#  ('streets', 'NNS'),
#  ('and', 'CC'),
#  ('thatched-roof', 'JJ'),
#  ('cottages', 'NNS'),
#  (',', ','),
#  ('exudes', 'VBZ'),
#  ('an', 'DT'),
#  ('aura', 'NN'),
#  ('of', 'IN'),
#  ('timeless', 'JJ'),
#  ('charm', 'NN'),
#  ('.', '.'),
#  ('Meadowvale', 'NNP'),
#  ('is', 'VBZ'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('its', 'PRP$'),
#  ('vibrant', 'JJ'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('villagers', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('their', 'PRP$'),
#  ('warm', 'JJ'),
#  ('smiles', 'NNS'),
#  ('and', 'CC'),
#  ('open', 'JJ'),
#  ('hearts', 'NNS'),
#  (',', ','),
#  ('create', 'VBP'),
#  ('an', 'DT'),
#  ('atmosphere', 'NN'),
#  ('of', 'IN'),
#  ('genuine', 'JJ'),
#  ('camaraderie', 'NN'),
#  ('and', 'CC'),
#  ('mutual', 'JJ'),
#  ('support', 'NN'),
#  ('.', '.'),
#  ('Each', 'DT'),
#  ('morning', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('greet', 'VBP'),
#  ('each', 'DT'),
#  ('other', 'JJ'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('local', 'JJ'),
#  ('market', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('bustling', 'VBG'),
#  ('hub', 'NN'),
#  ('of', 'IN'),
#  ('activity', 'NN'),
#  ('where', 'WRB'),
#  ('fresh', 'JJ'),
#  ('produce', 'NN'),
#  (',', ','),
#  ('homemade', 'JJR'),
#  ('goods', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('colorful', 'JJ'),
#  ('crafts', 'NNS'),
#  ('are', 'VBP'),
#  ('exchanged', 'VBN'),
#  ('with', 'IN'),
#  ('friendly', 'JJ'),
#  ('banter', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('village', 'NN'),
#  ('school', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('quaint', 'NN'),
#  ('building', 'NN'),
#  ('with', 'IN'),
#  ('ivy-clad', 'JJ'),
#  ('walls', 'NNS'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('pride', 'NN'),
#  ('of', 'IN'),
#  ('Meadowvale', 'NNP'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  (',', ','),
#  ('children', 'NNS'),
#  ('learn', 'VBP'),
#  ('not', 'RB'),
#  ('just', 'RB'),
#  ('academics', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('the', 'DT'),
#  ('values', 'NNS'),
#  ('of', 'IN'),
#  ('friendship', 'NN'),
#  (',', ','),
#  ('respect', 'NN'),
#  ('for', 'IN'),
#  ('nature', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('importance', 'NN'),
#  ('of', 'IN'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('teachers', 'NNS'),
#  ('are', 'VBP'),
#  ('dedicated', 'VBN'),
#  ('and', 'CC'),
#  ('nurturing', 'JJ'),
#  (',', ','),
#  ('often', 'RB'),
#  ('going', 'VBG'),
#  ('beyond', 'IN'),
#  ('their', 'PRP$'),
#  ('duties', 'NNS'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('every', 'DT'),
#  ('child', 'NN'),
#  ('flourishes', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('heart', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  ('stands', 'VBZ'),
#  ('the', 'DT'),
#  ('old', 'JJ'),
#  ('oak', 'NN'),
#  ('tree', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('legendary', 'JJ'),
#  ('figure', 'NN'),
#  ('in', 'IN'),
#  ('Meadowvale', 'NNP'),
#  ("'s", 'POS'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('tree', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('there', 'EX'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('founding', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  (',', ','),
#  ('its', 'PRP$'),
#  ('branches', 'NNS'),
#  ('bearing', 'VBG'),
#  ('witness', 'NN'),
#  ('to', 'TO'),
#  ('generations', 'NNS'),
#  ('of', 'IN'),
#  ('change', 'NN'),
#  ('and', 'CC'),
#  ('growth', 'NN'),
#  ('.', '.'),
#  ('Under', 'IN'),
#  ('its', 'PRP$'),
#  ('shade', 'NN'),
#  (',', ','),
#  ('villagers', 'NNS'),
#  ('often', 'RB'),
#  ('gather', 'VBP'),
#  ('for', 'IN'),
#  ('celebrations', 'NNS'),
#  (',', ','),
#  ('festivals', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('warm', 'JJ'),
#  (',', ','),
#  ('sunny', 'JJ'),
#  ('days', 'NNS'),
#  (',', ','),
#  ('simply', 'RB'),
#  ('to', 'TO'),
#  ('enjoy', 'VB'),
#  ('each', 'DT'),
#  ('other', 'JJ'),
#  ("'s", 'POS'),
#  ('company', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('the', 'DT'),
#  ('day', 'NN'),
#  ('progresses', 'VBZ'),
#  (',', ','),
#  ('the', 'DT'),
#  ('aroma', 'NN'),
#  ('of', 'IN'),
#  ('freshly', 'JJ'),
#  ('baked', 'VBN'),
#  ('bread', 'NN'),
#  ('and', 'CC'),
#  ('pastries', 'NNS'),
#  ('wafts', 'VBP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('bakery', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('favorite', 'JJ'),
#  ('stop', 'NN'),
#  ('for', 'IN'),
#  ('young', 'JJ'),
#  ('and', 'CC'),
#  ('old', 'JJ'),
#  ('alike', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('baker', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('his', 'PRP$'),
#  ('flour-dusted', 'JJ'),
#  ('apron', 'NN'),
#  ('and', 'CC'),
#  ('ever-present', 'JJ'),
#  ('smile', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('expert', 'NN'),
#  ('at', 'IN'),
#  ('his', 'PRP$'),
#  ('craft', 'NN'),
#  (',', ','),
#  ('baking', 'VBG'),
#  ('loaves', 'NNS'),
#  ('that', 'WDT'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('perfect', 'JJ'),
#  ('blend', 'NN'),
#  ('of', 'IN'),
#  ('crusty', 'NN'),
#  ('and', 'CC'),
#  ('soft', 'JJ'),
#  ('.', '.'),
#  ('Adjacent', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('bakery', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  ('caf̩', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('cozy', 'NN'),
#  ('spot', 'NN'),
#  ('where', 'WRB'),
#  ('locals', 'NNS'),
#  ('sip', 'VBP'),
#  ('coffee', 'NN'),
#  (',', ','),
#  ('exchange', 'NN'),
#  ('news', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('occasionally', 'RB'),
#  (',', ','),
#  ('burst', 'RB'),
#  ('into', 'IN'),
#  ('spontaneous', 'JJ'),
#  ('music', 'NN'),
#  ('sessions', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('caf̩', 'NN'),
#  ('walls', 'NNS'),
#  ('are', 'VBP'),
#  ('adorned', 'VBN'),
#  ('with', 'IN'),
#  ('photographs', 'NN'),
#  ('and', 'CC'),
#  ('paintings', 'NNS'),
#  (',', ','),
#  ('a', 'DT'),
#  ('testament', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('artistic', 'JJ'),
#  ('talents', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  ('inhabitants', 'NNS'),
#  ('.', '.'),
#  ('Meadowvale', 'NNP'),
#  ("'s", 'POS'),
#  ('surrounding', 'VBG'),
#  ('countryside', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('patchwork', 'NN'),
#  ('of', 'IN'),
#  ('lush', 'JJ'),
#  ('fields', 'NNS'),
#  (',', ','),
#  ('meandering', 'VBG'),
#  ('streams', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('wildflower', 'JJR'),
#  ('meadows', 'NNS'),
#  ('.', '.'),
#  ('Farmers', 'NNS'),
#  ('tend', 'VBP'),
#  ('their', 'PRP$'),
#  ('land', 'NN'),
#  ('with', 'IN'),
#  ('care', 'NN'),
#  ('and', 'CC'),
#  ('reverence', 'NN'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('methods', 'NNS'),
#  ('passed', 'VBD'),
#  ('down', 'RB'),
#  ('through', 'IN'),
#  ('generations', 'NNS'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('work', 'VBP'),
#  ('in', 'IN'),
#  ('harmony', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('land', 'NN'),
#  (',', ','),
#  ('ensuring', 'VBG'),
#  ('that', 'IN'),
#  ('their', 'PRP$'),
#  ('practices', 'NNS'),
#  ('are', 'VBP'),
#  ('sustainable', 'JJ'),
#  ('and', 'CC'),
#  ('environmentally', 'RB'),
#  ('friendly', 'JJ'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('evening', 'NN'),
#  ('approaches', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  ("'s", 'POS'),
#  ('pace', 'NN'),
#  ('slows', 'VBZ'),
#  ('down', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('streets', 'NNS'),
#  (',', ','),
#  ('once', 'RB'),
#  ('filled', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('sounds', 'NNS'),
#  ('of', 'IN'),
#  ('daily', 'JJ'),
#  ('life', 'NN'),
#  (',', ','),
#  ('become', 'VB'),
#  ('quiet', 'JJ'),
#  (',', ','),
#  ('save', 'VB'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('gentle', 'JJ'),
#  ('clinking', 'NN'),
#  ('of', 'IN'),
#  ('dishes', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('homes', 'NNS'),
#  ('as', 'IN'),
#  ('families', 'NNS'),
#  ('gather', 'VBP'),
#  ('for', 'IN'),
#  ('dinner', 'NN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('meals', 'NNS'),
#  ('are', 'VBP'),
#  ('often', 'RB'),
#  ('communal', 'JJ'),
#  ('affairs', 'NNS'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('stories', 'NNS'),
#  ('are', 'VBP'),
#  ('shared', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('laughter', 'NN'),
#  ('rings', 'NNS'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('walls', 'NNS'),
#  ('.', '.'),
#  ('Twice', 'RB'),
#  ('a', 'DT'),
#  ('month', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('village', 'NN'),
#  ('hosts', 'VBZ'),
#  ('a', 'DT'),
#  ('dance', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('town', 'NN'),
#  ('hall', 'NN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('events', 'NNS'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('highlight', 'NN'),
#  ('of', 'IN'),
#  ('Meadowvale', 'NNP'),
#  ("'s", 'POS'),
#  ('social', 'JJ'),
#  ('calendar', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('everyone', 'NN'),
#  (',', ','),
#  ('young', 'JJ'),
#  ('and', 'CC'),
#  ('old', 'JJ'),
#  (',', ','),
#  ('participating', 'VBG'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('dances', 'NNS'),
#  ('are', 'VBP'),
#  ('lively', 'RB'),
#  (',', ','),
#  ('filled', 'VBN'),
#  ('with', 'IN'),
#  ('music', 'NN'),
#  (',', ','),
#  ('joy', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('togetherness', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('heart', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('night', 'NN'),
#  ('falls', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('sky', 'NN'),
#  ('above', 'IN'),
#  ('Meadowvale', 'NNP'),
#  ('becomes', 'VBZ'),
#  ('a', 'DT'),
#  ('canvas', 'NN'),
#  ('of', 'IN'),
#  ('stars', 'NNS'),
#  (',', ','),
#  ('unmarred', 'JJ'),
#  ('by', 'IN'),
#  ('city', 'NN'),
#  ('lights', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('villagers', 'NNS'),
#  (',', ','),
#  ('who', 'WP'),
#  ('know', 'VBP'),
#  ('the', 'DT'),
#  ('importance', 'NN'),
#  ('of', 'IN'),
#  ('preserving', 'VBG'),
#  ('the', 'DT'),
#  ('beauty', 'NN'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('natural', 'JJ'),
#  ('surroundings', 'NNS'),
#  (',', ','),
#  ('take', 'VBP'),
#  ('a', 'DT'),
#  ('moment', 'NN'),
#  ('to', 'TO'),
#  ('gaze', 'VB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('night', 'NN'),
#  ('sky', 'NN'),
#  (',', ','),
#  ('finding', 'VBG'),
#  ('peace', 'NN'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('vastness', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('Meadowvale', 'NNP'),
#  (',', ','),
#  ('life', 'NN'),
#  ('may', 'MD'),
#  ('seem', 'VB'),
#  ('simple', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('rich', 'JJ'),
#  ('in', 'IN'),
#  ('ways', 'NNS'),
#  ('that', 'IN'),
#  ('matter', 'NN'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  (',', ','),
#  ('people', 'NNS'),
#  ('understand', 'VBP'),
#  ('the', 'DT'),
#  ('value', 'NN'),
#  ('of', 'IN'),
#  ('connections', 'NNS'),
#  (',', ','),
#  ('of', 'IN'),
#  ('living', 'NN'),
#  ('in', 'IN'),
#  ('tune', 'NN'),
#  ('with', 'IN'),
#  ('nature', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('of', 'IN'),
#  ('preserving', 'VBG'),
#  ('traditions', 'NNS'),
#  ('that', 'WDT'),
#  ('bind', 'VBP'),
#  ('them', 'PRP'),
#  ('together', 'RB'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('where', 'WRB'),
#  ('every', 'DT'),
#  ('individual', 'NN'),
#  ('contributes', 'VBZ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('tapestry', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('community', 'NN'),
#  (',', ','),
#  ('creating', 'VBG'),
#  ('a', 'DT'),
#  ('life', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('deeply', 'RB'),
#  ('fulfilling', 'JJ'),
#  ('and', 'CC'),
#  ('harmonious', 'JJ'),
#  ('.', '.')]

# %%
! pip install svgling
# Out:
# Collecting svgling
#   Downloading svgling-0.4.0-py3-none-any.whl (23 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#                                               0.0/67.1 kB ? eta -:--:--
#      ------------------------                 41.0/67.1 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 67.1/67.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.4.0 svgwrite-1.4.3
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
entities = nltk.chunk.ne_chunk(pos)
entities
# Out:
# Tree('S', [Tree('GPE', [('Deep', 'NNP')]), ('in', 'IN'), ('the', 'DT'), ('valley', 'NN'), (',', ','), ('surrounded', 'VBN'), ('by', 'IN'), ('towering', 'VBG'), ('hills', 'NNS'), ('and', 'CC'), ('dense', 'NN'), ('forests', 'NNS'), (',', ','), ('lies', 'VBZ'), ('the', 'DT'), ('quaint', 'JJ'), ('village', 'NN'), ('of', 'IN'), Tree('GPE', [('Meadowvale', 'NNP')]), ('.', '.'), ('It', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('place', 'NN'), ('seemingly', 'RB'), ('frozen', 'VBN'), ('in', 'IN'), ('time', 'NN'), (',', ','), ('where', 'WRB'), ('traditions', 'NNS'), ('are', 'VBP'), ('cherished', 'VBN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('hustle', 'NN'), ('of', 'IN'), ('modern', 'JJ'), ('life', 'NN'), ('feels', 'NNS'), ('like', 'IN'), ('a', 'DT'), ('distant', 'JJ'), ('concept', 'NN'), ('.', '.'), ('The', 'DT'), ('village', 'NN'), (',', ','), ('with', 'IN'), ('its', 'PRP$'), ('cobblestone', 'NN'), ('streets', 'NNS'), ('and', 'CC'), ('thatched-roof', 'JJ'), ('cottages', 'NNS'), (',', ','), ('exudes', 'VBZ'), ('an', 'DT'), ('aura', 'NN'), ('of', 'IN'), ('timeless', 'JJ'), ('charm', 'NN'), ('.', '.'), Tree('PERSON', [('Meadowvale', 'NNP')]), ('is', 'VBZ'), ('known', 'VBN'), ('for', 'IN'), ('its', 'PRP$'), ('vibrant', 'JJ'), ('community', 'NN'), ('.', '.'), ('The', 'DT'), ('villagers', 'NNS'), (',', ','), ('with', 'IN'), ('their', 'PRP$'), ('warm', 'JJ'), ('smiles', 'NNS'), ('and', 'CC'), ('open', 'JJ'), ('hearts', 'NNS'), (',', ','), ('create', 'VBP'), ('an', 'DT'), ('atmosphere', 'NN'), ('of', 'IN'), ('genuine', 'JJ'), ('camaraderie', 'NN'), ('and', 'CC'), ('mutual', 'JJ'), ('support', 'NN'), ('.', '.'), ('Each', 'DT'), ('morning', 'NN'), (',', ','), ('they', 'PRP'), ('greet', 'VBP'), ('each', 'DT'), ('other', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('local', 'JJ'), ('market', 'NN'), (',', ','), ('a', 'DT'), ('bustling', 'VBG'), ('hub', 'NN'), ('of', 'IN'), ('activity', 'NN'), ('where', 'WRB'), ('fresh', 'JJ'), ('produce', 'NN'), (',', ','), ('homemade', 'JJR'), ('goods', 'NNS'), (',', ','), ('and', 'CC'), ('colorful', 'JJ'), ('crafts', 'NNS'), ('are', 'VBP'), ('exchanged', 'VBN'), ('with', 'IN'), ('friendly', 'JJ'), ('banter', 'NN'), ('.', '.'), ('The', 'DT'), ('village', 'NN'), ('school', 'NN'), (',', ','), ('a', 'DT'), ('quaint', 'NN'), ('building', 'NN'), ('with', 'IN'), ('ivy-clad', 'JJ'), ('walls', 'NNS'), (',', ','), ('is', 'VBZ'), ('the', 'DT'), ('pride', 'NN'), ('of', 'IN'), Tree('GPE', [('Meadowvale', 'NNP')]), ('.', '.'), ('Here', 'RB'), (',', ','), ('children', 'NNS'), ('learn', 'VBP'), ('not', 'RB'), ('just', 'RB'), ('academics', 'NNS'), (',', ','), ('but', 'CC'), ('also', 'RB'), ('the', 'DT'), ('values', 'NNS'), ('of', 'IN'), ('friendship', 'NN'), (',', ','), ('respect', 'NN'), ('for', 'IN'), ('nature', 'NN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('importance', 'NN'), ('of', 'IN'), ('community', 'NN'), ('.', '.'), ('The', 'DT'), ('teachers', 'NNS'), ('are', 'VBP'), ('dedicated', 'VBN'), ('and', 'CC'), ('nurturing', 'JJ'), (',', ','), ('often', 'RB'), ('going', 'VBG'), ('beyond', 'IN'), ('their', 'PRP$'), ('duties', 'NNS'), ('to', 'TO'), ('ensure', 'VB'), ('every', 'DT'), ('child', 'NN'), ('flourishes', 'NNS'), ('.', '.'), ('In', 'IN'), ('the', 'DT'), ('heart', 'NN'), ('of', 'IN'), ('the', 'DT'), ('village', 'NN'), ('stands', 'VBZ'), ('the', 'DT'), ('old', 'JJ'), ('oak', 'NN'), ('tree', 'NN'), (',', ','), ('a', 'DT'), ('legendary', 'JJ'), ('figure', 'NN'), ('in', 'IN'), Tree('GPE', [('Meadowvale', 'NNP')]), ("'s", 'POS'), ('history', 'NN'), ('.', '.'), ('It', 'PRP'), ("'s", 'VBZ'), ('said', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('tree', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('there', 'EX'), ('since', 'IN'), ('the', 'DT'), ('founding', 'NN'), ('of', 'IN'), ('the', 'DT'), ('village', 'NN'), (',', ','), ('its', 'PRP$'), ('branches', 'NNS'), ('bearing', 'VBG'), ('witness', 'NN'), ('to', 'TO'), ('generations', 'NNS'), ('of', 'IN'), ('change', 'NN'), ('and', 'CC'), ('growth', 'NN'), ('.', '.'), ('Under', 'IN'), ('its', 'PRP$' ...
